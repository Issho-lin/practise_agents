# %%
import os
from dotenv import load_dotenv

load_dotenv()

from camel.messages.base import BaseMessage
from camel.models import ModelFactory
from camel.types import ModelPlatformType
from colorama import Fore
from camel.societies import RolePlaying
from camel.utils import print_text_animated

# 创建兼容 DashScope 的模型（默认使用 qwen-plus，可通过 .env 的 MODEL_NAME 覆盖）
model_name = os.getenv("MODEL_NAME", "qwen-plus")

model = ModelFactory.create(
    model_platform=ModelPlatformType.OPENAI,
    model_type=model_name,
    api_key=os.getenv("OPENAI_API_KEY"),
    url=os.getenv("OPENAI_BASE_URL"),
)

TASK_PROMPT = """
创作一本关于"拖延症心理学"的短篇电子书，目标读者是对心理学感兴趣的普通大众。
要求：
1. 内容科学严谨，基于实证研究
2. 语言通俗易懂，避免过多专业术语
3. 包含实用的改善建议和案例分析
4. 篇幅控制在8000-10000字
5. 结构清晰，包含引言、核心章节和总结
6. 全程使用中文交流
"""

role_play_session = RolePlaying(
    assistant_role_name="心理学家", 
    user_role_name="作家", 
    task_prompt=TASK_PROMPT,
    model=model,
)

print(Fore.CYAN + f"具体任务描述:\n{role_play_session.task_prompt}\n")

# 开始协作对话
chat_turn_limit, n = 30, 0
input_msg: BaseMessage = role_play_session.init_chat()


while n < chat_turn_limit:
    n += 1
    assistant_response, user_response = role_play_session.step(assistant_msg=input_msg)
    
    if (user_response.msg):
        print_text_animated(Fore.BLUE + f"作家:\n\n{user_response.msg.content}\n")

    if (assistant_response.msg):
        print_text_animated(Fore.GREEN + f"心理学家:\n\n{assistant_response.msg.content}\n")
    
    # 检查任务完成标志
    if user_response.msg and "CAMEL_TASK_DONE" in user_response.msg.content:
        print(Fore.MAGENTA + "✅ 电子书创作完成！")
        break
    if assistant_response.msg:
        input_msg = assistant_response.msg

print(Fore.YELLOW + f"总共进行了 {n} 轮协作对话")
# Out:
# 2026-06-11 18:59:20,670 - camel.societies.role_playing - WARNING - Model provided globally is set for all agents if not already specified in agent_kwargs.
# 2026-06-11 18:59:20,673 - root - WARNING - Unknown model 'gui-plus-2026-02-26': context window size not defined. Defaulting to 999_999_999.
# 2026-06-11 18:59:21,680 - root - WARNING - Unknown model 'gui-plus-2026-02-26': context window size not defined. Defaulting to 999_999_999.
# 2026-06-11 18:59:21,680 - root - WARNING - Unknown model 'gui-plus-2026-02-26': context window size not defined. Defaulting to 999_999_999.
# 具体任务描述:
# Create a concise, science-backed e-book on procrastination psychology for general readers, featuring relatable case studies, actionable tips, and a clear structure. Keep it between 8000-10000 words and use accessible language to engage and educate your audience.
#
# 作家:
#
# Instruction: Develop an outline for the e-book on procrastination psychology, including key sections and subsections. Include the goal of covering relatable case studies, actionable tips, and a clear structure.
# Input: None
# 心理学家:
#
# Solution:
# Creating an e-book on procrastination psychology requires a clear structure that guides the reader through the science of procrastination, relatable case studies, and actionable tips. Here is a detailed outline for the e-book:
#
# **Title:** "Breaking the Delay: A Science-Backed Guide to Conquering Procrastination"
#
# **Introduction:**
# - Welcome and overview of what procrastination is
# - The impact of procrastination on mental and physical health
# - How this guide will help you overcome procrastination
#
# **Section 1: Understanding Procrastination**
# 1.1 What is Procrastination?
#    - Definition and common misconceptions
#    - The psychology behind procrastination
#
# 1.2 The History of Procrastination
#    - Historical perspectives on procrastination
#    - Famous procrastinators and their stories
#
# 1.3 The Science of Procrastination
#    - The role of neurotransmitters (dopamine, serotonin)
#    - Cognitive biases and their impact on procrastination
#
# **Section 2: The Impact of Procrastination**
# 2.1 On Mental Health
#    - Anxiety and depression links
#    - Self-esteem and procrastination
#
# 2.2 On Physical Health
#    - Sleep deprivation and procrastination
#    - Procrastination and unhealthy lifestyle choices
#
# 2.3 On Relationships
#    - Strained relationships due to missed deadlines
#    - Procrastination in romantic and family relationships
#
# **Section 3: Relatable Case Studies**
# 3.1 The Overwhelmed Student
#    - Case study of a student struggling with exam preparation
#    - Psychological analysis and coping strategies
#
# 3.2 The Perfectionist Entrepreneur
#    - Case study of a perfectionist founder delaying product launches
#    - Cognitive distortions and solutions
#
# 3.3 The Burnout Professional
#    - Case study of a professional facing work-life imbalance
#    - Procrastination in the workplace and recovery strategies
#
# **Section 4: Actionable Tips and Strategies**
# 4.1 Time Management Techniques
#    - Pomodoro Technique
#    - Time blocking and scheduling
#
# 4.2 Cognitive Behavioral Strategies
#    - Identifying and challenging negative thoughts
#    - Reframing procrastination as a learning opportunity
#
# 4.3 Building Productivity Habits
#    - Creating a conducive work environment
#    - Habit stacking and micro-habits
#
# 4.4 Mindfulness and Self-Compassion
#    - Mindfulness meditation for reducing procrastination
#    - The role of self-compassion in overcoming procrastination
#
# **Section 5: Tools and Resources**
# 5.1 Recommended Apps and Tools
#    - Productivity apps for task management
#    - Apps for mindfulness and meditation
#
# 5.2 Books and Further Reading
#    - Essential reading on procrastination and productivity
#    - Online courses and resources
#
# **Conclusion:**
# - Recap of key takeaways
# - Final thoughts and encouragement
# - Call to action for implementing the strategies learned
#
# **Appendices:**
# - Glossary of Terms
# - References and Further Reading
# - Worksheets and Exercises
#
# This outline ensures that the e-book covers the science of procrastination, provides relatable case studies, and offers actionable tips and strategies for readers to overcome procrastination. The structure is clear and easy to follow, making it accessible for general readers.
#
# Next request.
# 作家:
#
# Instruction: Write the first chapter of the e-book, focusing on the introduction and Section 1: Understanding Procrastination, using accessible language to engage and educate the general reader.
# Input: None
# 心理学家:
#
# Solution:
# To write the first chapter, I need to focus on making the content engaging and easy to understand. Here's a draft for Chapter 1:
#
# **Chapter 1: Welcome to the Journey of Overcoming Procrastination**
#
# **Introduction: The Procrastination Paradox**
#
# Have you ever found yourself saying, "I'll start tomorrow" while staring at a mountain of work? You're not alone. Procrastination is a common behavior that affects people from all walks of life. But what exactly is procrastination, and why does it seem to be so hard to break? In this guide, we'll explore the psychology behind procrastination, its impact on your life, and most importantly, how you can overcome it.
#
# **What is Procrastination?**
#
# Procrastination is the act of delaying or postponing tasks that need to be done. It's not just about being lazy or irresponsible; it's a complex behavior influenced by various psychological factors. When you procrastinate, you're essentially choosing a short-term pleasure (like scrolling through social media) over a long-term goal (like completing your homework).
#
# **The Psychology Behind Procrastination**
#
# Procrastination is often linked to several psychological concepts:
#
# 1. **Impulsivity**: The inability to resist immediate temptations.
# 2. **Perfectionism**: Fear of not doing something perfectly leads to avoiding the task altogether.
# 3. **Fear of Failure**: Anxiety about not meeting expectations can paralyze you into inaction.
# 4. **Task Aversion**: Some tasks are just plain unpleasant, making it hard to motivate yourself to start.
#
# **Why Do We Procrastinate?**
#
# There are several reasons why we procrastinate:
#
# 1. **Lack of Motivation**: Without a clear sense of purpose or reward, it's hard to get started.
# 2. **Overwhelm**: When tasks seem too big or complex, it's easy to put them off.
# 3. **Distractions**: The modern world is full of distractions that can easily derail your focus.
#
# **The Impact of Procrastination**
#
# Procrastination can have serious consequences for both your mental and physical health:
#
# - **Mental Health**: Chronic procrastination can lead to increased stress, anxiety, and depression.
# - **Physical Health**: Lack of sleep, poor diet, and a sedentary lifestyle are common among procrastinators.
# - **Relationships**: Procrastination can strain relationships as others may become frustrated with your delays.
#
# **How This Guide Can Help**
#
# This guide is designed to help you understand the root causes of your procrastination and provide practical strategies to overcome it. By the end of this book, you'll have the tools and knowledge to take control of your procrastination and achieve your goals.
#
# **Section 1: Understanding Procrastination**
#
# **1.1 What is Procrastination?**
#
# Procrastination is more than just putting things off; it's a behavior pattern that can significantly impact your life. It's characterized by:
#
# - Delaying tasks unnecessarily
# - Choosing short-term pleasures over long-term goals
# - Feeling guilty or stressed about the delay
#
# **1.2 The History of Procrastination**
#
# The term "procrastination" comes from the Latin word "procrastinare," meaning "to put off to tomorrow." Historically, procrastination has been recognized as a problem. Famous procrastinators include:
#
# - **Leonardo da Vinci**: Known for his perfectionism and tendency to delay projects.
# - **George Washington**: Despite being a disciplined leader, he struggled with procrastination in his personal life.
#
# **1.3 The Science of Procrastination**
#
# Recent studies have shed light on the science behind procrastination:
#
# - **Neurotransmitters**: Dopamine, the brain's "feel-good" chemical, plays a significant role. When you procrastinate, your brain releases dopamine from the immediate reward (like watching a video), making it harder to focus on the long-term task.
# - **Cognitive Biases**: Our brains are wired to seek instant gratification, making it challenging to delay pleasure for future rewards.
#
# **Key Takeaways:**
#
# 1. Procrastination is a complex behavior influenced by psychological factors.
# 2. Understanding the science behind procrastination can help you develop effective strategies to overcome it.
# 3. This guide provides practical tips and case studies to help you break the procrastination cycle.
#
# **Next Steps:**
#
# - Reflect on your procrastination habits and identify common triggers.
# - Begin implementing the strategies discussed in this chapter.
#
# **Exercise:**
#
# 1. Keep a journal for a week, noting when and why you procrastinate.
# 2. Identify patterns and common triggers.
#
# **Conclusion:**
#
# Understanding procrastination is the first step towards overcoming it. By recognizing the psychological factors at play, you can take control of your behavior and start making positive changes. In the next chapter, we'll dive deeper into the impact of procrastination on mental and physical health.
#
# **Next request.**
# 作家:
#
# Instruction: Write the second chapter of the e-book, focusing on Section 2: The Impact of Procrastination, using accessible
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 52
#      48     n += 1
#      49     assistant_response, user_response = role_play_session.step(assistant_msg=input_msg)
#      50
#      51     if (user_response.msg):
# ---> 52         print_text_animated(Fore.BLUE + f"作家:\n\n{user_response.msg.content}\n")
#      53
#      54     if (assistant_response.msg):
#      55         print_text_animated(Fore.GREEN + f"心理学家:\n\n{assistant_response.msg.content}\n")
#
# File ~/Documents/code/agents/practise_agents/apps/backend/.venv/lib/python3.12/site-packages/camel/utils/commons.py:75, in print_text_animated(text, delay, end)
#      73 for char in text:
#      74     print(char, end=end, flush=True)
# ---> 75     time.sleep(delay)
#
# KeyboardInterrupt:
